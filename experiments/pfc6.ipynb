# %% [markdown]
# # HMM-GLM on the CRCRS pfc-6 Dataset

# %% [markdown]
# ## 1 Load the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Wedge
import pandas as pd
import torch
from torch import nn
from torch.nn import functional as F
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

from hmmglm.models import naive, onehot
from hmmglm import distributions, inference, utils

# %%
def load_data(dt: float = 20, T: float = 15000):
    n_time_bins = int(T / dt)
    session = "200104"
    behavior = pd.read_csv(
        f"../data/{session}/{session}_Behavior.dat",
        sep="\t",
        header=None,
    )
    behavior.columns = [
        "trial_start_time",
        "trial_end_time",
        "rule",
        "outcome",
        "choice",
        "light_position",
    ]
    behavior.replace(
        {
            "rule": {
                1: "go right",
                2: "go light",
                3: "go left",
                4: "go dark",
            },
            "outcome": {1: "correct", 0: "incorrect"},
            "choice": {1: "left", 0: "right"},
            "light_position": {1: "left", 0: "right"},
        },
        inplace=True,
    )

    raw_position = pd.read_table(
        f"../data/{session}/{session}_Pos.dat", header=None
    )
    raw_position.columns = ["time", "x", "y"]
    raw_spike_data = pd.read_table(
        f"../data/{session}/{session}_SpikeData.dat", header=None
    )
    raw_spike_data.columns = ["time", "cell_id"]

    spike_time_by_cell_id = [
        (neuron, i["time"].values)
        for neuron, i in raw_spike_data.groupby("cell_id")
    ]
    n_neurons = len(spike_time_by_cell_id)
    n_trials = len(behavior)

    start_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"] - 5000
    )
    end_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"] - 5000 + T
    )
    trial_start_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"]
    )
    trial_end_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_end_time"]
    )

    behavior["trajectory"] = None
    behavior["trial_start_position"] = None
    behavior["trial_end_position"] = None
    spikes = torch.zeros((n_trials, n_time_bins, n_neurons))
    for trial in range(n_trials):
        time_bins = np.linspace(
            behavior.at[trial, "trial_start_time"] - 5000,
            behavior.at[trial, "trial_start_time"] - 5000 + T,
            n_time_bins + 1,
        )
        for neuron in range(n_neurons):
            spikes[trial, :, neuron] = torch.tensor(
                np.histogram(
                    spike_time_by_cell_id[neuron][1],
                    bins=time_bins,
                )[0]
            )
        
        behavior.at[trial, "trajectory"] = raw_position.iloc[
            start_idx_list[trial] : end_idx_list[trial]
        ][["time", "x", "y"]].values
        behavior.at[trial, "trial_start_position"] = raw_position.iloc[
            trial_start_idx_list[trial]
        ][["x", "y"]].values
        behavior.at[trial, "trial_end_position"] = raw_position.iloc[
            trial_end_idx_list[trial]
        ][["x", "y"]].values
    spikes = spikes.to(
        torch.float32
    )  # (n_trials, n_time_bins, n_neurons)
    return spikes, behavior

# %%
spikes, behavior = load_data()
print(spikes.shape)
behavior.head()
# Out:
# torch.Size([54, 750, 18])
#    trial_start_time  trial_end_time     rule    outcome choice light_position  \
# 0         1968759.3       1971595.3  go dark  incorrect   left           left
# 1         1993249.2       1996285.4  go dark  incorrect   left           left
# 2         2005927.9       2014169.0  go dark  incorrect   left           left
# 3         2023611.3       2033854.4  go dark    correct   left          right
# 4         2093010.5       2096880.8  go dark  incorrect   left           left
#
#                                           trajectory trial_start_position  \
# 0  [[1963787.9, 173.2, 187.2], [1963821.3, 173.0,...       [169.4, 134.2]
# 1  [[1988277.8, 155.8, 163.1], [1988311.2, 155.9,...       [168.1, 135.9]
# 2  [[2000956.5, 147.1, 92.3], [2000989.9, 146.5, ...       [176.1, 204.8]
# 3  [[2018639.9, 119.3, 81.6], [2018673.3, 118.8, ...       [182.4, 184.7]
# 4  [[2088039.1, 173.8, 192.2], [2088072.5, 174.6,...       [152.9, 129.2]
#
#   trial_end_position
# 0      [257.1, 49.1]
# 1      [254.9, 47.9]
# 2      [254.0, 46.1]
# 3      [255.8, 46.2]
# 4      [255.1, 44.4]

# %% [markdown]
# ## 2 Configure the HMM-GLM

# %% [markdown]
# Generated spike count of neuron $n$ at time $t$
# $$ x_{t,n} \sim \mathcal{P}(f_{t,n}) $$
#
# Firing rate of neuron $n$ at time $t$
# $$ f_{t,n} = \operatorname{softplus}\left(b_{z_t, n} + \sum_{n'=1}^N \underbrace{\left(\sum_{k=1}^K x_{t-k,n'} \cdot \phi_{z_t,n\gets n',k}\right)}_{\text{convolved history, $n\gets n'$, state $z_t$}}\right) $$
# * $z_t\in\{1,\dots,S\}$: HMM state at time $t$
# * $b_{s,n}$: bias (background intensity) of neuron $n$ in state $s\in\{1,\dots,S\}$
# * $\phi_{s,n\gets n',:} \in \mathbb{R}^K$: temporal convolution kernel corresponds to the influence from neuron $n'$ to neuron $n$ if in state $s$.

# %%
n_trials, n_time_bins, n_neurons = spikes.shape
n_states = 4
kernel_size = 5

# %%
torch.manual_seed(0)

decoder_hmmglm = naive.HMMGLM(
    n_states=n_states,
    n_neurons=n_neurons,
    kernel_size=kernel_size,
    activation="softplus",  # or "sigmoid", etc
)

# %% [markdown]
# ## 3 Train HMM-GLM

# %%
def train_hmmglm(
    decoder: naive.HMMGLM,
    optimizer: torch.optim.Optimizer,
    spikes: torch.FloatTensor,
    n_epochs: int = 100,
    forward_backward_every_n_epochs: int = 1,
    print_freq: int = 1,
) -> torch.FloatTensor:
    
    n_trials, n_time_bins, n_neurons = spikes.shape

    gamma_list = [None for _ in range(n_trials)]
    xi_list = [None for _ in range(n_trials)]

    df_log = pd.DataFrame(index=range(n_epochs), columns=["loss", "conditional_log_prob", "expected_log_prob"])

    for epoch in range(n_epochs):
        for trial in range(n_trials):
            x = spikes[trial]  # (n_time_bins, n_neurons)
            x_pred_mean = decoder(x)  # (n_states, n_time_bins, n_neurons)
            emission_log_prob = distributions.poisson_log_likelihood(
                x[None, :, :], x_pred_mean
            ).sum(dim=-1).T  # (n_time_bins, n_states)

            if epoch % forward_backward_every_n_epochs == 0:
                gamma_list[trial], xi_list[trial] = inference.forward_backward(
                    emission_log_prob, decoder.transition_matrix, algorithm="logsumexp"
                )
            
            expected_log_prob = (
                    inference.baum_welch(
                    emission_log_prob,
                    decoder.transition_matrix,
                    gamma_list[trial],
                    xi_list[trial],
                )
                / x.shape[0]
            )

            loss = -expected_log_prob
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            df_log.at[epoch, "loss"] = loss.item() / n_trials
            df_log.at[epoch, "conditional_log_prob"] = (
                emission_log_prob[torch.arange(n_time_bins), gamma_list[trial].argmax(dim=-1)].sum().item() / n_trials
            )
            df_log.at[epoch, "expected_log_prob"] = expected_log_prob.item() / n_trials
        
        if epoch % print_freq == 0:
            print(epoch, df_log.loc[epoch], flush=True)
    
    return df_log

# %%
optimizer = torch.optim.AdamW(
    decoder_hmmglm.parameters(),
    lr=5e-3,
)
n_epochs = 100
forward_backward_every_n_epochs = 4

# %%
df_log = train_hmmglm(
    decoder_hmmglm,
    optimizer,
    spikes,
    n_epochs=n_epochs,
    forward_backward_every_n_epochs=forward_backward_every_n_epochs,
    print_freq=1,
)
# Out:
# 0 loss                     0.111261
# conditional_log_prob   -82.932825
# expected_log_prob       -0.111261
# Name: 0, dtype: object
# 1 loss                     0.097901
# conditional_log_prob   -72.957687
# expected_log_prob       -0.097901
# Name: 1, dtype: object
# 2 loss                    0.093851
# conditional_log_prob   -69.93722
# expected_log_prob      -0.093851
# Name: 2, dtype: object
# 3 loss                    0.091829
# conditional_log_prob   -68.43108
# expected_log_prob      -0.091829
# Name: 3, dtype: object
# 4 loss                     0.090407
# conditional_log_prob   -66.499023
# expected_log_prob       -0.090407
# Name: 4, dtype: object
# 5 loss                     0.089547
# conditional_log_prob   -65.861256
# expected_log_prob       -0.089547
# Name: 5, dtype: object
# 6 loss                      0.08899
# conditional_log_prob   -65.447867
# expected_log_prob        -0.08899
# Name: 6, dtype: object
# 7 loss                     0.088566
# conditional_log_prob   -65.130575
# expected_log_prob       -0.088566
# Name: 7, dtype: object
# 8 loss                     0.08839
# conditional_log_prob   -64.75666
# expected_log_prob       -0.08839
# Name: 8, dtype: object
# 9 loss                     0.088095
# conditional_log_prob   -64.549334
# expected_log_prob       -0.088095
# Name: 9, dtype: object
# 10 loss                     0.087855
# conditional_log_prob   -64.373508
# expected_log_prob       -0.087855
# Name: 10, dtype: object
# 11 loss                     0.087643
# conditional_log_prob   -64.215816
# expected_log_prob       -0.087643
# Name: 11, dtype: object
# 12 loss                     0.087686
# conditional_log_prob   -63.984045
# expected_log_prob       -0.087686
# Name: 12, dtype: object
# 13 loss                     0.087518
# conditional_log_prob   -63.867992
# expected_log_prob       -0.087518
# Name: 13, dtype: object
# 14 loss                      0.08737
# conditional_log_prob   -63.760842
# expected_log_prob        -0.08737
# Name: 14, dtype: object
# 15 loss                     0.087233
# conditional_log_prob   -63.659876
# expected_log_prob       -0.087233
# Name: 15, dtype: object
# 16 loss                     0.087291
# conditional_log_prob   -63.446334
# expected_log_prob       -0.087291
# Name: 16, dtype: object
# 17 loss                     0.087159
# conditional_log_prob   -63.350034
# expected_log_prob       -0.087159
# Name: 17, dtype: object
# 18 loss                     0.087045
# conditional_log_prob   -63.266272
# expected_log_prob       -0.087045
# Name: 18, dtype: object
# 19 loss                     0.086941
# conditional_log_prob   -63.188983
# expected_log_prob       -0.086941
# Name: 19, dtype: object
# 20 loss                    0.086972
# conditional_log_prob   -62.99004
# expected_log_prob      -0.086972
# Name: 20, dtype: object
# 21 loss                     0.086867
# conditional_log_prob   -62.919357
# expected_log_prob       -0.086867
# Name: 21, dtype: object
# 22 loss                     0.086777
# conditional_log_prob   -62.857526
# expected_log_prob       -0.086777
# Name: 22, dtype: object
# 23 loss                     0.086694
# conditional_log_prob   -62.800026
# expected_log_prob       -0.086694
# Name: 23, dtype: object
# 24 loss                     0.086678
# conditional_log_prob   -62.653673
# expected_log_prob       -0.086678
# Name: 24, dtype: object
# 25 loss                     0.086591
# conditional_log_prob   -62.591973
# expected_log_prob       -0.086591
# Name: 25, dtype: object
# 26 loss                     0.086516
# conditional_log_prob   -62.538859
# expected_log_prob       -0.086516
# Name: 26, dtype: object
# 27 loss                     0.086447
# conditional_log_prob   -62.490479
# expected_log_prob       -0.086447
# Name: 27, dtype: object
# 28 loss                     0.086353
# conditional_log_prob   -62.434887
# expected_log_prob       -0.086353
# Name: 28, dtype: object
# 29 loss                     0.08628
# conditional_log_prob   -62.38029
# expected_log_prob       -0.08628
# Name: 29, dtype: object
# 30 loss                     0.086217
# conditional_log_prob   -62.334138
# expected_log_prob       -0.086217
# Name: 30, dtype: object
# 31 loss                     0.08616
# conditional_log_prob   -62.29282
# expected_log_prob       -0.08616
# Name: 31, dtype: object
# 32 loss                     0.086059
# conditional_log_prob   -62.228181
# expected_log_prob       -0.086059
# Name: 32, dtype: object
# 33 loss                        0.086
# conditional_log_prob   -62.183802
# expected_log_prob          -0.086
# Name: 33, dtype: object
# 34 loss                     0.085948
# conditional_log_prob   -62.146177
# expected_log_prob       -0.085948
# Name: 34, dtype: object
# 35 loss                       0.0859
# conditional_log_prob   -62.112345
# expected_log_prob         -0.0859
# Name: 35, dtype: object
# 36 loss                     0.085806
# conditional_log_prob   -62.175013
# expected_log_prob       -0.085806
# Name: 36, dtype: object
# 37 loss                     0.085756
# conditional_log_prob   -62.139359
# expected_log_prob       -0.085756
# Name: 37, dtype: object
# 38 loss                     0.085713
# conditional_log_prob   -62.108706
# expected_log_prob       -0.085713
# Name: 38, dtype: object
# 39 loss                     0.085673
# conditional_log_prob   -62.081082
# expected_log_prob       -0.085673
# Name: 39, dtype: object
# 40 loss                     0.085585
# conditional_log_prob   -62.004322
# expected_log_prob       -0.085585
# Name: 40, dtype: object
# 41 loss                     0.085544
# conditional_log_prob   -61.972756
# expected_log_prob       -0.085544
# Name: 41, dtype: object
# 42 loss                     0.085508
# conditional_log_prob   -61.945511
# expected_log_prob       -0.085508
# Name: 42, dtype: object
# 43 loss                    0.085475
# conditional_log_prob   -61.92098
# expected_log_prob      -0.085475
# Name: 43, dtype: object
# 44 loss                     0.085398
# conditional_log_prob   -61.920356
# expected_log_prob       -0.085398
# Name: 44, dtype: object
# 45 loss                     0.085364
# conditional_log_prob   -61.896615
# expected_log_prob       -0.085364
# Name: 45, dtype: object
# 46 loss                     0.085334
# conditional_log_prob   -61.875787
# expected_log_prob       -0.085334
# Name: 46, dtype: object
# 47 loss                     0.085307
# conditional_log_prob   -61.856757
# expected_log_prob       -0.085307
# Name: 47, dtype: object
# 48 loss                    0.085237
# conditional_log_prob   -61.88529
# expected_log_prob      -0.085237
# Name: 48, dtype: object
# 49 loss                      0.08521
# conditional_log_prob   -61.867974
# expected_log_prob        -0.08521
# Name: 49, dtype: object
# 50 loss                     0.085185
# conditional_log_prob   -61.852367
# expected_log_prob       -0.085185
# Name: 50, dtype: object
# 51 loss                     0.085162
# conditional_log_prob   -61.837805
# expected_log_prob       -0.085162
# Name: 51, dtype: object
# 52 loss                     0.085092
# conditional_log_prob   -61.958804
# expected_log_prob       -0.085092
# Name: 52, dtype: object
# 53 loss                     0.085068
# conditional_log_prob   -61.942252
# expected_log_prob       -0.085068
# Name: 53, dtype: object
# 54 loss                     0.085047
# conditional_log_prob   -61.927318
# expected_log_prob       -0.085047
# Name: 54, dtype: object
# 55 loss                     0.085028
# conditional_log_prob   -61.913484
# expected_log_prob       -0.085028
# Name: 55, dtype: object
# 56 loss                     0.084952
# conditional_log_prob   -61.877387
# expected_log_prob       -0.084952
# Name: 56, dtype: object
# 57 loss                     0.084932
# conditional_log_prob   -61.861229
# expected_log_prob       -0.084932
# Name: 57, dtype: object
# 58 loss                     0.084913
# conditional_log_prob   -61.847019
# expected_log_prob       -0.084913
# Name: 58, dtype: object
# 59 loss                     0.084896
# conditional_log_prob   -61.834043
# expected_log_prob       -0.084896
# Name: 59, dtype: object
# 60 loss                     0.084819
# conditional_log_prob   -61.942907
# expected_log_prob       -0.084819
# Name: 60, dtype: object
# 61 loss                     0.084801
# conditional_log_prob   -61.928078
# expected_log_prob       -0.084801
# Name: 61, dtype: object
# 62 loss                     0.084784
# conditional_log_prob   -61.915039
# expected_log_prob       -0.084784
# Name: 62, dtype: object
# 63 loss                     0.084769
# conditional_log_prob   -61.903171
# expected_log_prob       -0.084769
# Name: 63, dtype: object
# 64 loss                     0.084697
# conditional_log_prob   -61.900192
# expected_log_prob       -0.084697
# Name: 64, dtype: object
# 65 loss                      0.08468
# conditional_log_prob   -61.886773
# expected_log_prob        -0.08468
# Name: 65, dtype: object
# 66 loss                     0.084665
# conditional_log_prob   -61.874982
# expected_log_prob       -0.084665
# Name: 66, dtype: object
# 67 loss                     0.084652
# conditional_log_prob   -61.864258
# expected_log_prob       -0.084652
# Name: 67, dtype: object
# 68 loss                     0.084585
# conditional_log_prob   -61.893392
# expected_log_prob       -0.084585
# Name: 68, dtype: object
# 69 loss                      0.08457
# conditional_log_prob   -61.881384
# expected_log_prob        -0.08457
# Name: 69, dtype: object
# 70 loss                     0.084557
# conditional_log_prob   -61.870841
# expected_log_prob       -0.084557
# Name: 70, dtype: object
# 71 loss                     0.084545
# conditional_log_prob   -61.861224
# expected_log_prob       -0.084545
# Name: 71, dtype: object
# 72 loss                     0.084482
# conditional_log_prob   -61.896516
# expected_log_prob       -0.084482
# Name: 72, dtype: object
# 73 loss                     0.084468
# conditional_log_prob   -61.884906
# expected_log_prob       -0.084468
# Name: 73, dtype: object
# 74 loss                     0.084456
# conditional_log_prob   -61.874702
# expected_log_prob       -0.084456
# Name: 74, dtype: object
# 75 loss                     0.084445
# conditional_log_prob   -61.865429
# expected_log_prob       -0.084445
# Name: 75, dtype: object
# 76 loss                    0.084386
# conditional_log_prob   -61.87221
# expected_log_prob      -0.084386
# Name: 76, dtype: object
# 77 loss                     0.084373
# conditional_log_prob   -61.861785
# expected_log_prob       -0.084373
# Name: 77, dtype: object
# 78 loss                     0.084362
# conditional_log_prob   -61.852593
# expected_log_prob       -0.084362
# Name: 78, dtype: object
# 79 loss                     0.084353
# conditional_log_prob   -61.844265
# expected_log_prob       -0.084353
# Name: 79, dtype: object
# 80 loss                       0.0843
# conditional_log_prob   -61.837574
# expected_log_prob         -0.0843
# Name: 80, dtype: object
# 81 loss                     0.084289
# conditional_log_prob   -61.829332
# expected_log_prob       -0.084289
# Name: 81, dtype: object
# 82 loss                      0.08428
# conditional_log_prob   -61.821818
# expected_log_prob        -0.08428
# Name: 82, dtype: object
# 83 loss                     0.084271
# conditional_log_prob   -61.814959
# expected_log_prob       -0.084271
# Name: 83, dtype: object
# 84 loss                     0.084226
# conditional_log_prob   -61.847584
# expected_log_prob       -0.084226
# Name: 84, dtype: object
# 85 loss                    0.084217
# conditional_log_prob   -61.84172
# expected_log_prob      -0.084217
# Name: 85, dtype: object
# 86 loss                     0.08421
# conditional_log_prob   -61.83591
# expected_log_prob       -0.08421
# Name: 86, dtype: object
# 87 loss                     0.084203
# conditional_log_prob   -61.830584
# expected_log_prob       -0.084203
# Name: 87, dtype: object
# 88 loss                     0.084164
# conditional_log_prob   -61.879693
# expected_log_prob       -0.084164
# Name: 88, dtype: object
# 89 loss                    0.084157
# conditional_log_prob   -61.87448
# expected_log_prob      -0.084157
# Name: 89, dtype: object
# 90 loss                     0.084151
# conditional_log_prob   -61.869453
# expected_log_prob       -0.084151
# Name: 90, dtype: object
# 91 loss                    0.084145
# conditional_log_prob    -61.8648
# expected_log_prob      -0.084145
# Name: 91, dtype: object
# 92 loss                     0.084111
# conditional_log_prob   -61.873038
# expected_log_prob       -0.084111
# Name: 92, dtype: object
# 93 loss                     0.084105
# conditional_log_prob   -61.868679
# expected_log_prob       -0.084105
# Name: 93, dtype: object
# 94 loss                       0.0841
# conditional_log_prob   -61.864484
# expected_log_prob         -0.0841
# Name: 94, dtype: object
# 95 loss                     0.084095
# conditional_log_prob   -61.860546
# expected_log_prob       -0.084095
# Name: 95, dtype: object
# 96 loss                     0.084065
# conditional_log_prob   -61.865682
# expected_log_prob       -0.084065
# Name: 96, dtype: object
# 97 loss                      0.08406
# conditional_log_prob   -61.861916
# expected_log_prob        -0.08406
# Name: 97, dtype: object
# 98 loss                     0.084056
# conditional_log_prob   -61.858326
# expected_log_prob       -0.084056
# Name: 98, dtype: object
# 99 loss                     0.084052
# conditional_log_prob   -61.854953
# expected_log_prob       -0.084052
# Name: 99, dtype: object

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3), layout="constrained")
axs[0].plot(df_log["loss"])
axs[0].set_title("Loss")
axs[1].plot(df_log["conditional_log_prob"])
axs[1].set_title("Conditional log prob")
axs[2].plot(df_log["expected_log_prob"])
axs[2].set_title("Expected log prob")
fig.supxlabel("Epoch")
# Out:
# Text(0.5, 0.01, 'Epoch')

# %% [markdown]
# ## 4 Check and visualize the result

# %%
with torch.no_grad():
    decoder_hmmglm.eval()
    weight = decoder_hmmglm.conv.weight.sum(dim=-1).reshape(n_states, n_neurons, n_neurons)

    fig, axs = plt.subplots(1, n_states, figsize=(12, 4), layout="constrained")
    for state in range(n_states):
        ax = axs[state]
        ax.matshow(weight[state], vmin=-5, vmax=5, cmap="seismic")
        ax.set_title(f"State {state}")
        ax.set(xticks=[], yticks=[])

# %%
def plot_frame(ax):
    transform = np.array([[-1 / 2, np.sqrt(3) / 2], [-np.sqrt(3) / 2, -1 / 2]])
    radius = 40
    theta = 210 / 360 * 2 * np.pi
    start = np.array([radius * np.cos(theta), radius * np.sin(theta)])
    arm_length = 125
    theta = 330 / 360 * 2 * np.pi
    end = np.array([radius * np.cos(theta), radius * np.sin(theta)])
    one_arm = np.array(
        [
            [start[0], start[0], end[0], end[0]],
            [start[1], start[1] - arm_length, end[1] - arm_length, end[1]],
        ]
    )
    ax.plot(one_arm[0], one_arm[1], "k")
    one_arm = transform @ one_arm
    ax.plot(one_arm[0], one_arm[1], "k")
    one_arm = transform @ one_arm
    ax.plot(one_arm[0], one_arm[1], "k")

    # ax.text(0, -160, "root", fontsize=15, va="center", ha="center")
    ax.set_xlim(-160, 160)
    ax.set_ylim(-190, 130)
    ax.axis("off")
    ax.set_aspect("equal")


def plot_states(ax, behavior_ser, inferred_states, markersize: int = 6):
    trajectory_time = behavior_ser["trajectory"][:, 0]
    ax.matshow(inferred_states[None, :], vmin=0, vmax=9, cmap="tab10", aspect="auto")
    ax.set(xticks=[], yticks=[])

    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"

    trial_start_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_start_time"])
        / len(trajectory_time)
        * len(inferred_states)
    )
    trial_end_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_end_time"])
        / len(trajectory_time)
        * len(inferred_states)
    )
    ax.plot(trial_start_idx, 0, ">k", markersize=markersize)
    ax.plot(trial_end_idx, 0, marker, markersize=markersize)


def plot_soft_states(ax, behavior_ser, gamma, markersize: int = 6):
    trajectory_time = behavior_ser["trajectory"][:, 0]
    n_states = gamma.shape[1]
    for state in range(n_states):
        ax.matshow(
            state * np.ones((1, gamma.shape[0])),
            vmin=0,
            vmax=9,
            cmap="tab10",
            aspect="auto",
            alpha=gamma[None, :, state],
        )
    ax.set(xticks=[], yticks=[])

    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"

    trial_start_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_start_time"])
        / len(trajectory_time)
        * len(gamma)
    )
    trial_end_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_end_time"])
        / len(trajectory_time)
        * len(gamma)
    )
    ax.plot(trial_start_idx, 0, ">k", markersize=markersize)
    ax.plot(trial_end_idx, 0, marker, markersize=markersize)


def plot_trajectory(
    ax, behavior_ser: pd.Series, inferred_states: torch.Tensor, n_points: int | None = None, truncate: tuple[int|None, int|None] = (0, -1), markersize: int = 10
):
    theta = 185 / 360 * 2 * np.pi
    transform = np.array(
        [[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]
    )
    translation = np.array([155, 122])
    trial_start_position = behavior_ser["trial_start_position"]
    trial_start_position = transform @ trial_start_position + translation
    ax.plot(
        trial_start_position[0],
        trial_start_position[1],
        ">k",
        markersize=markersize,
    )
    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"
    if behavior_ser["light_position"] == "right":
        ax.add_patch(Circle((140, 90), 10, fc="gold", edgecolor="black"))
        ax.add_patch(Wedge((140, 80), 5, 180, 360, fc="none", edgecolor="black"))
    else:
        ax.add_patch(Circle((-140, 90), 10, fc="gold", edgecolor="black"))
        ax.add_patch(Wedge((-140, 80), 6, 180, 360, fc="none", edgecolor="black"))
    trial_end_position = behavior_ser["trial_end_position"]
    trial_end_position = transform @ trial_end_position + translation
    ax.plot(
        trial_end_position[0],
        trial_end_position[1],
        marker,
        markersize=markersize,
    )
    ax.text(0, 90, f"{behavior_ser["rule"]}", fontsize=15, ha="center", va="center")

    trajectory = behavior_ser["trajectory"][:, 1:]

    if n_points is None:
        n_points = min(len(trajectory), len(inferred_states))
    trajectory = trajectory[np.linspace(0, len(trajectory) - 1, n_points, dtype=int)]
    trajectory = trajectory @ transform.T + translation
    inferred_states = inferred_states[
        np.linspace(0, len(inferred_states) - 1, n_points, dtype=int)
    ]
    ax.scatter(
        trajectory[truncate[0]:truncate[1], 0],
        trajectory[truncate[0]:truncate[1], 1],
        c=inferred_states[truncate[0]:truncate[1]],
        vmin=0,
        vmax=9,
        cmap="tab10",
        s=1,
        zorder=10,
    )

# %%
n_rows = (n_trials - 1) // 5 + 1
n_points = 450
fig, axs = plt.subplots(n_rows, 5, figsize=(12, 2.2 * n_rows), layout="constrained")
axs = axs.flatten()

gamma_list = [None for _ in range(n_trials)]
inferred_states_list = [None for _ in range(n_trials)]

with torch.no_grad():
    for trial in range(n_trials):
    # for trial in range(5):
        x = spikes[trial]  # (n_time_bins, n_neurons)
        x_pred_mean = decoder_hmmglm(x)  # (n_states, n_time_bins, n_neurons)
        emission_log_prob = distributions.poisson_log_likelihood(
            x[None, :, :], x_pred_mean
        ).sum(dim=-1).T  # (n_time_bins, n_states)

        gamma_list[trial], _ = inference.forward_backward(
            emission_log_prob, decoder_hmmglm.transition_matrix, algorithm="logsumexp"
        )
        inferred_states_list[trial] = inference.viterbi(
            emission_log_prob, decoder_hmmglm.transition_matrix
        )
        ax = axs[trial]
        plot_frame(ax)
        plot_trajectory(ax, behavior.loc[trial], inferred_states_list[trial], n_points=n_points, truncate=(150, -1))
        ax_divider = make_axes_locatable(ax)
        ax_states = ax_divider.append_axes("top", size="20%", pad=0)
        plot_soft_states(ax_states, behavior.loc[trial], gamma_list[trial])
        # plot_states(ax_states, behavior.loc[trial], inferred_states_list[trial])


    for trial in range(n_trials, len(axs)):
        axs[trial].axis("off")
