# %% [markdown]
# # One-hot HMM-GLM on the CRCRS pfc-6 Dataset
#
# ![](../assets/schematic.png)

# %% [markdown]
# ## 1 Load the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.animation as animation
from matplotlib.patches import Circle, Wedge
import pandas as pd
import torch
from torch import nn
from torch.nn import functional as F
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

from hmmglm.models import onehot
from hmmglm import distributions, inference

# %%
def load_data(dt: float = 20, T: float = 15000):
    n_time_bins = int(T / dt)
    session = "200104"
    behavior = pd.read_csv(
        f"../data/{session}/{session}_Behavior.dat",
        sep="\t",
        header=None,
    )
    behavior.columns = [
        "trial_start_time",
        "trial_end_time",
        "rule",
        "outcome",
        "choice",
        "light_position",
    ]
    behavior.replace(
        {
            "rule": {
                1: "go right",
                2: "go light",
                3: "go left",
                4: "go dark",
            },
            "outcome": {1: "correct", 0: "incorrect"},
            "choice": {1: "left", 0: "right"},
            "light_position": {1: "left", 0: "right"},
        },
        inplace=True,
    )

    raw_position = pd.read_table(
        f"../data/{session}/{session}_Pos.dat", header=None
    )
    raw_position.columns = ["time", "x", "y"]
    raw_spike_data = pd.read_table(
        f"../data/{session}/{session}_SpikeData.dat", header=None
    )
    raw_spike_data.columns = ["time", "cell_id"]

    spike_time_by_cell_id = [
        (neuron, i["time"].values)
        for neuron, i in raw_spike_data.groupby("cell_id")
    ]
    n_neurons = len(spike_time_by_cell_id)
    n_trials = len(behavior)

    start_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"] - 5000
    )
    end_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"] - 5000 + T
    )
    trial_start_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"]
    )
    trial_end_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_end_time"]
    )

    behavior["trajectory"] = None
    behavior["trial_start_position"] = None
    behavior["trial_end_position"] = None
    spikes = torch.zeros((n_trials, n_time_bins, n_neurons))
    for trial in range(n_trials):
        time_bins = np.linspace(
            behavior.at[trial, "trial_start_time"] - 5000,
            behavior.at[trial, "trial_start_time"] - 5000 + T,
            n_time_bins + 1,
        )
        for neuron in range(n_neurons):
            spikes[trial, :, neuron] = torch.tensor(
                np.histogram(
                    spike_time_by_cell_id[neuron][1],
                    bins=time_bins,
                )[0]
            )
        
        behavior.at[trial, "trajectory"] = raw_position.iloc[
            start_idx_list[trial] : end_idx_list[trial]
        ][["time", "x", "y"]].values
        behavior.at[trial, "trial_start_position"] = raw_position.iloc[
            trial_start_idx_list[trial]
        ][["x", "y"]].values
        behavior.at[trial, "trial_end_position"] = raw_position.iloc[
            trial_end_idx_list[trial]
        ][["x", "y"]].values
    spikes = spikes.to(
        torch.float32
    )  # (n_trials, n_time_bins, n_neurons)
    return spikes, behavior

# %%
spikes, behavior = load_data()
print(spikes.shape)
behavior.head()
# Out:
# torch.Size([54, 750, 18])
#    trial_start_time  trial_end_time     rule    outcome choice light_position  \
# 0         1968759.3       1971595.3  go dark  incorrect   left           left
# 1         1993249.2       1996285.4  go dark  incorrect   left           left
# 2         2005927.9       2014169.0  go dark  incorrect   left           left
# 3         2023611.3       2033854.4  go dark    correct   left          right
# 4         2093010.5       2096880.8  go dark  incorrect   left           left
#
#                                           trajectory trial_start_position  \
# 0  [[1963787.9, 173.2, 187.2], [1963821.3, 173.0,...       [169.4, 134.2]
# 1  [[1988277.8, 155.8, 163.1], [1988311.2, 155.9,...       [168.1, 135.9]
# 2  [[2000956.5, 147.1, 92.3], [2000989.9, 146.5, ...       [176.1, 204.8]
# 3  [[2018639.9, 119.3, 81.6], [2018673.3, 118.8, ...       [182.4, 184.7]
# 4  [[2088039.1, 173.8, 192.2], [2088072.5, 174.6,...       [152.9, 129.2]
#
#   trial_end_position
# 0      [257.1, 49.1]
# 1      [254.9, 47.9]
# 2      [254.0, 46.1]
# 3      [255.8, 46.2]
# 4      [255.1, 44.4]

# %% [markdown]
# ## 2 Configure the One-hot HMM-GLM

# %%
n_trials, n_time_bins, n_neurons = spikes.shape
n_states = 4
kernel_size = 5

# %%
torch.manual_seed(0)

decoder = onehot.OneHotHMMGLM(
    n_states=n_states,
    n_neurons=n_neurons,
    kernel_size=kernel_size,
    activation="softplus",  # or "sigmoid", etc
    share_bias=False,  # 4 states dont' share the same bias vector
    share_kernel=True,  # 4 states share the same kernel
    diag_setting="none",  # don't treat diagonal elements differently
    adjacency_distribution="categorical",  # or "gumbel-softmax"
    adjacency_exists=True,  # adjacency is the one-hot encoding of [inh, no, exc] rather than [inh, exc]
)

# decoder = onehot.OneHotHMMGLM(
#     n_states=n_states,
#     n_neurons=n_neurons,
#     kernel_size=kernel_size,
#     activation="softplus",  # or "sigmoid", etc
#     share_bias=False,
#     share_kernel=False,
#     diag_setting="free",  # don't treat diagonal elements differently
#     adjacency_distribution="categorical",  # or "gumbel-softmax"
#     adjacency_exists=True,  # adjacency is the one-hot encoding of [inh, no, exc] rather than [inh, exc]
# )

# %% [markdown]
# Let's also fix the convolution kernel for simplicity.

# %%
kernel = torch.exp(-torch.arange(5)).flip(dims=(-1,))
kernel = kernel / kernel.sum()

fig, ax = plt.subplots(1, 1, figsize=(6, 4), layout="constrained")
ax.plot(kernel)
ax.set(
    xticks=[0, 1, 2, 3, 4],
    xticklabels=["$t-5$", "$t-4$", "$t-3$", "$t-2$", "$t-1$"],
    title="Convolutional kernel",
)

kernel = kernel.unsqueeze(0).unsqueeze(0).expand_as(decoder.conv_weight).contiguous()  # (shared across states, n_neurons, n_neurons, kernel_size)
decoder.conv_weight = kernel  # set the kernel
decoder.parametrizations.conv_weight.original.requires_grad = False  # freeze the kernel

# %% [markdown]
# ## 3 Train One-hot HMM-GLM

# %%
def train_onehot_hmmglm(
    decoder: onehot.OneHotHMMGLM,
    optimizer: torch.optim.Optimizer,
    spikes: torch.FloatTensor,
    n_epochs: int = 100,
    forward_backward_every_n_epochs: int = 1,
    print_freq: int = 1,
) -> torch.FloatTensor:
    
    n_trials, n_time_bins, n_neurons = spikes.shape

    gamma_list = [None for _ in range(n_trials)]
    xi_list = [None for _ in range(n_trials)]

    df_log = pd.DataFrame(index=range(n_epochs), columns=["loss", "conditional_log_prob", "expected_log_prob", "adjacency_log_prob", "adjacency_entropy"])

    for epoch in range(n_epochs):
        for trial in range(n_trials):
            x = spikes[trial]  # (n_time_bins, n_neurons)
            x_pred_mean = decoder(x)  # (n_states, n_time_bins, n_neurons)
            emission_log_prob = distributions.poisson_log_likelihood(
                x[None, :, :], x_pred_mean
            ).sum(dim=-1).T  # (n_time_bins, n_states)

            if epoch % forward_backward_every_n_epochs == 0:
                gamma_list[trial], xi_list[trial] = inference.forward_backward(
                    emission_log_prob, decoder.transition_matrix, algorithm="logsumexp"
                )
            
            expected_log_prob = (
                    inference.baum_welch(
                    emission_log_prob,
                    decoder.transition_matrix,
                    gamma_list[trial],
                    xi_list[trial],
                )
                / x.shape[0]
            )

            adjacency = decoder.adjacency
            log_adjacency = F.log_softmax(
                decoder.parametrizations["adjacency"].original, dim=-1
            )

            if decoder.adjacency_distribution == "gumbel-softmax":
                logit_adjacency_prior = decoder.logit_adjacency_prior.expand_as(
                    log_adjacency
                )
                adjacency_log_prob = distributions.gumbel_softmax_log_likelihood_log_input(
                    log_adjacency,
                    logit_adjacency_prior,
                    tau=0.5,
                ).sum()
            elif decoder.adjacency_distribution == "categorical":
                log_adjacency_prior = F.log_softmax(
                    decoder.logit_adjacency_prior, dim=-1
                ).expand_as(adjacency)
                adjacency_log_prob = (adjacency * log_adjacency_prior).sum()
            else:
                raise ValueError(
                    f"Invalid adjacency_distribution: {decoder.adjacency_distribution}"
                )
            
            adjacency_entropy = -(adjacency * log_adjacency).sum()

            loss = -expected_log_prob - adjacency_log_prob
            if decoder.adjacency_distribution == "categorical":
                loss += adjacency_entropy
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            df_log.at[epoch, "loss"] = loss.item() / n_trials
            df_log.at[epoch, "conditional_log_prob"] = (
                emission_log_prob[torch.arange(n_time_bins), gamma_list[trial].argmax(dim=-1)].sum().item() / n_trials
            )
            df_log.at[epoch, "expected_log_prob"] = expected_log_prob.item() / n_trials
            df_log.at[epoch, "adjacency_log_prob"] = adjacency_log_prob.item() / n_trials
            df_log.at[epoch, "adjacency_entropy"] = adjacency_entropy.item() / n_trials
        
        decoder.parametrizations["adjacency"].original.data = F.log_softmax(
            decoder.parametrizations["adjacency"].original.data, dim=-1
        ).clamp(-20, 0)
        
        if epoch % print_freq == 0:
            print(epoch, df_log.loc[epoch], flush=True)
    
    return df_log

# %%
optimizer = torch.optim.AdamW(
    decoder.parameters(),
    lr=1e-2,
)
n_epochs = 100
forward_backward_every_n_epochs = 4

# %%
df_log = train_onehot_hmmglm(
    decoder,
    optimizer,
    spikes,
    n_epochs=n_epochs,
    forward_backward_every_n_epochs=forward_backward_every_n_epochs,
    print_freq=1,
)
# Out:
# 0 loss                     46.500515
# conditional_log_prob   -117.435845
# expected_log_prob        -0.159457
# adjacency_log_prob      -23.444356
# adjacency_entropy        22.896701
# Name: 0, dtype: object
# 1 loss                    28.511081
# conditional_log_prob   -91.784324
# expected_log_prob       -0.124876
# adjacency_log_prob     -14.474303
# adjacency_entropy       13.911901
# Name: 1, dtype: object
# 2 loss                    15.151883
# conditional_log_prob   -83.162028
# expected_log_prob       -0.113487
# adjacency_log_prob      -7.737022
# adjacency_entropy        7.301374
# Name: 2, dtype: object
# 3 loss                     8.780975
# conditional_log_prob   -80.511411
# expected_log_prob        -0.10996
# adjacency_log_prob       -4.58038
# adjacency_entropy        4.090635
# Name: 3, dtype: object
# 4 loss                      5.47643
# conditional_log_prob   -73.117459
# expected_log_prob       -0.098535
# adjacency_log_prob      -2.957896
# adjacency_entropy        2.419999
# Name: 4, dtype: object
# 5 loss                     3.938838
# conditional_log_prob   -70.974433
# expected_log_prob       -0.095607
# adjacency_log_prob      -2.198897
# adjacency_entropy        1.644334
# Name: 5, dtype: object
# 6 loss                     3.144452
# conditional_log_prob   -70.285251
# expected_log_prob       -0.094667
# adjacency_log_prob      -1.806348
# adjacency_entropy        1.243437
# Name: 6, dtype: object
# 7 loss                     2.641072
# conditional_log_prob   -69.500199
# expected_log_prob        -0.09362
# adjacency_log_prob      -1.557737
# adjacency_entropy        0.989715
# Name: 7, dtype: object
# 8 loss                     2.292844
# conditional_log_prob   -68.618765
# expected_log_prob       -0.092467
# adjacency_log_prob      -1.385926
# adjacency_entropy        0.814452
# Name: 8, dtype: object
# 9 loss                     2.039396
# conditional_log_prob   -68.252984
# expected_log_prob       -0.091981
# adjacency_log_prob      -1.260682
# adjacency_entropy        0.686733
# Name: 9, dtype: object
# 10 loss                     1.847381
# conditional_log_prob   -67.913678
# expected_log_prob       -0.091531
# adjacency_log_prob      -1.165826
# adjacency_entropy        0.590024
# Name: 10, dtype: object
# 11 loss                     1.697576
# conditional_log_prob   -67.621103
# expected_log_prob       -0.091142
# adjacency_log_prob      -1.091834
# adjacency_entropy          0.5146
# Name: 11, dtype: object
# 12 loss                     1.577939
# conditional_log_prob   -67.576289
# expected_log_prob       -0.090835
# adjacency_log_prob      -1.032736
# adjacency_entropy        0.454368
# Name: 12, dtype: object
# 13 loss                     1.480425
# conditional_log_prob   -67.313232
# expected_log_prob       -0.090488
# adjacency_log_prob      -0.984612
# adjacency_entropy        0.405325
# Name: 13, dtype: object
# 14 loss                     1.399877
# conditional_log_prob   -67.216996
# expected_log_prob       -0.090358
# adjacency_log_prob      -0.944781
# adjacency_entropy        0.364738
# Name: 14, dtype: object
# 15 loss                    1.332223
# conditional_log_prob   -67.09403
# expected_log_prob      -0.090196
# adjacency_log_prob     -0.911351
# adjacency_entropy       0.330676
# Name: 15, dtype: object
# 16 loss                    1.274536
# conditional_log_prob   -66.88751
# expected_log_prob      -0.089839
# adjacency_log_prob     -0.882953
# adjacency_entropy       0.301745
# Name: 16, dtype: object
# 17 loss                     1.225111
# conditional_log_prob   -66.730713
# expected_log_prob       -0.089625
# adjacency_log_prob      -0.858576
# adjacency_entropy        0.276911
# Name: 17, dtype: object
# 18 loss                     1.182266
# conditional_log_prob   -66.575304
# expected_log_prob       -0.089417
# adjacency_log_prob      -0.837454
# adjacency_entropy        0.255395
# Name: 18, dtype: object
# 19 loss                    1.145056
# conditional_log_prob   -66.60513
# expected_log_prob      -0.089455
# adjacency_log_prob     -0.819001
# adjacency_entropy       0.236599
# Name: 19, dtype: object
# 20 loss                     1.112101
# conditional_log_prob   -66.502722
# expected_log_prob       -0.089284
# adjacency_log_prob       -0.80276
# adjacency_entropy        0.220057
# Name: 20, dtype: object
# 21 loss                     1.082914
# conditional_log_prob   -66.398049
# expected_log_prob       -0.089142
# adjacency_log_prob      -0.788371
# adjacency_entropy        0.205401
# Name: 21, dtype: object
# 22 loss                     1.057232
# conditional_log_prob   -66.556528
# expected_log_prob       -0.089351
# adjacency_log_prob      -0.775544
# adjacency_entropy        0.192338
# Name: 22, dtype: object
# 23 loss                     1.033704
# conditional_log_prob   -66.317084
# expected_log_prob       -0.089028
# adjacency_log_prob      -0.764046
# adjacency_entropy        0.180629
# Name: 23, dtype: object
# 24 loss                    1.012722
# conditional_log_prob   -66.24929
# expected_log_prob      -0.088951
# adjacency_log_prob     -0.753689
# adjacency_entropy       0.170082
# Name: 24, dtype: object
# 25 loss                     0.993718
# conditional_log_prob   -66.190348
# expected_log_prob       -0.088866
# adjacency_log_prob      -0.744315
# adjacency_entropy        0.160536
# Name: 25, dtype: object
# 26 loss                     0.976463
# conditional_log_prob   -66.149735
# expected_log_prob       -0.088808
# adjacency_log_prob      -0.735795
# adjacency_entropy        0.151861
# Name: 26, dtype: object
# 27 loss                     0.960713
# conditional_log_prob   -66.107481
# expected_log_prob       -0.088748
# adjacency_log_prob       -0.72802
# adjacency_entropy        0.143944
# Name: 27, dtype: object
# 28 loss                     0.946277
# conditional_log_prob   -65.930488
# expected_log_prob       -0.088685
# adjacency_log_prob      -0.720899
# adjacency_entropy        0.136693
# Name: 28, dtype: object
# 29 loss                     0.932997
# conditional_log_prob   -65.875307
# expected_log_prob       -0.088613
# adjacency_log_prob      -0.714355
# adjacency_entropy         0.13003
# Name: 29, dtype: object
# 30 loss                     0.920771
# conditional_log_prob   -65.836878
# expected_log_prob       -0.088563
# adjacency_log_prob      -0.708321
# adjacency_entropy        0.123887
# Name: 30, dtype: object
# 31 loss                     0.909468
# conditional_log_prob   -65.803973
# expected_log_prob       -0.088521
# adjacency_log_prob      -0.702741
# adjacency_entropy        0.118206
# Name: 31, dtype: object
# 32 loss                     0.898963
# conditional_log_prob   -65.728416
# expected_log_prob       -0.088458
# adjacency_log_prob      -0.697567
# adjacency_entropy        0.112938
# Name: 32, dtype: object
# 33 loss                     0.889205
# conditional_log_prob   -65.690588
# expected_log_prob       -0.088409
# adjacency_log_prob      -0.692755
# adjacency_entropy         0.10804
# Name: 33, dtype: object
# 34 loss                     0.880117
# conditional_log_prob   -65.659804
# expected_log_prob       -0.088369
# adjacency_log_prob      -0.688271
# adjacency_entropy        0.103476
# Name: 34, dtype: object
# 35 loss                     0.871625
# conditional_log_prob   -65.630285
# expected_log_prob       -0.088331
# adjacency_log_prob      -0.684083
# adjacency_entropy        0.099211
# Name: 35, dtype: object
# 36 loss                     0.863667
# conditional_log_prob   -65.592326
# expected_log_prob       -0.088288
# adjacency_log_prob       -0.68016
# adjacency_entropy        0.095219
# Name: 36, dtype: object
# 37 loss                      0.85611
# conditional_log_prob   -65.490379
# expected_log_prob       -0.088157
# adjacency_log_prob       -0.67648
# adjacency_entropy        0.091473
# Name: 37, dtype: object
# 38 loss                     0.849203
# conditional_log_prob   -65.547377
# expected_log_prob        -0.08823
# adjacency_log_prob      -0.673021
# adjacency_entropy        0.087952
# Name: 38, dtype: object
# 39 loss                     0.842597
# conditional_log_prob   -65.522877
# expected_log_prob       -0.088198
# adjacency_log_prob      -0.669763
# adjacency_entropy        0.084636
# Name: 39, dtype: object
# 40 loss                     0.836404
# conditional_log_prob   -65.517415
# expected_log_prob       -0.088207
# adjacency_log_prob      -0.666689
# adjacency_entropy        0.081508
# Name: 40, dtype: object
# 41 loss                     0.830489
# conditional_log_prob   -65.476359
# expected_log_prob       -0.088153
# adjacency_log_prob      -0.663785
# adjacency_entropy        0.078552
# Name: 41, dtype: object
# 42 loss                     0.824919
# conditional_log_prob   -65.458541
# expected_log_prob       -0.088129
# adjacency_log_prob      -0.661036
# adjacency_entropy        0.075754
# Name: 42, dtype: object
# 43 loss                     0.819639
# conditional_log_prob   -65.441429
# expected_log_prob       -0.088107
# adjacency_log_prob       -0.65843
# adjacency_entropy        0.073102
# Name: 43, dtype: object
# 44 loss                     0.814647
# conditional_log_prob   -65.425939
# expected_log_prob       -0.088105
# adjacency_log_prob      -0.655957
# adjacency_entropy        0.070584
# Name: 44, dtype: object
# 45 loss                    0.809888
# conditional_log_prob   -65.41428
# expected_log_prob       -0.08809
# adjacency_log_prob     -0.653606
# adjacency_entropy       0.068192
# Name: 45, dtype: object
# 46 loss                     0.805343
# conditional_log_prob   -65.392085
# expected_log_prob        -0.08806
# adjacency_log_prob      -0.651368
# adjacency_entropy        0.065915
# Name: 46, dtype: object
# 47 loss                     0.801027
# conditional_log_prob   -65.381275
# expected_log_prob       -0.088046
# adjacency_log_prob      -0.649236
# adjacency_entropy        0.063745
# Name: 47, dtype: object
# 48 loss                     0.796943
# conditional_log_prob   -65.358136
# expected_log_prob       -0.088066
# adjacency_log_prob      -0.647202
# adjacency_entropy        0.061675
# Name: 48, dtype: object
# 49 loss                    0.793005
# conditional_log_prob   -65.34493
# expected_log_prob      -0.088047
# adjacency_log_prob      -0.64526
# adjacency_entropy       0.059698
# Name: 49, dtype: object
# 50 loss                     0.789247
# conditional_log_prob   -65.337542
# expected_log_prob       -0.088036
# adjacency_log_prob      -0.643403
# adjacency_entropy        0.057808
# Name: 50, dtype: object
# 51 loss                     0.785641
# conditional_log_prob   -65.322772
# expected_log_prob       -0.088016
# adjacency_log_prob      -0.641625
# adjacency_entropy           0.056
# Name: 51, dtype: object
# 52 loss                     0.782259
# conditional_log_prob   -65.310642
# expected_log_prob       -0.088068
# adjacency_log_prob      -0.639923
# adjacency_entropy        0.054268
# Name: 52, dtype: object
# 53 loss                     0.778954
# conditional_log_prob   -65.305519
# expected_log_prob       -0.088056
# adjacency_log_prob      -0.638291
# adjacency_entropy        0.052607
# Name: 53, dtype: object
# 54 loss                    0.775782
# conditional_log_prob   -65.29834
# expected_log_prob      -0.088044
# adjacency_log_prob     -0.636725
# adjacency_entropy       0.051014
# Name: 54, dtype: object
# 55 loss                      0.77273
# conditional_log_prob   -65.285414
# expected_log_prob       -0.088025
# adjacency_log_prob      -0.635221
# adjacency_entropy        0.049484
# Name: 55, dtype: object
# 56 loss                     0.769865
# conditional_log_prob   -65.181514
# expected_log_prob       -0.088077
# adjacency_log_prob      -0.633776
# adjacency_entropy        0.048013
# Name: 56, dtype: object
# 57 loss                    0.767066
# conditional_log_prob   -65.18335
# expected_log_prob      -0.088081
# adjacency_log_prob     -0.632386
# adjacency_entropy       0.046599
# Name: 57, dtype: object
# 58 loss                     0.764339
# conditional_log_prob   -65.166499
# expected_log_prob       -0.088054
# adjacency_log_prob      -0.631048
# adjacency_entropy        0.045237
# Name: 58, dtype: object
# 59 loss                     0.761729
# conditional_log_prob   -65.158388
# expected_log_prob       -0.088043
# adjacency_log_prob      -0.629759
# adjacency_entropy        0.043926
# Name: 59, dtype: object
# 60 loss                     0.759251
# conditional_log_prob   -65.047201
# expected_log_prob       -0.088071
# adjacency_log_prob      -0.628517
# adjacency_entropy        0.042663
# Name: 60, dtype: object
# 61 loss                     0.756824
# conditional_log_prob   -65.036856
# expected_log_prob       -0.088059
# adjacency_log_prob       -0.62732
# adjacency_entropy        0.041445
# Name: 61, dtype: object
# 62 loss                    0.754484
# conditional_log_prob   -65.02908
# expected_log_prob       -0.08805
# adjacency_log_prob     -0.626165
# adjacency_entropy        0.04027
# Name: 62, dtype: object
# 63 loss                     0.752226
# conditional_log_prob   -65.022502
# expected_log_prob       -0.088042
# adjacency_log_prob       -0.62505
# adjacency_entropy        0.039135
# Name: 63, dtype: object
# 64 loss                     0.750055
# conditional_log_prob   -65.003762
# expected_log_prob       -0.088043
# adjacency_log_prob      -0.623972
# adjacency_entropy        0.038039
# Name: 64, dtype: object
# 65 loss                     0.747948
# conditional_log_prob   -64.999182
# expected_log_prob       -0.088037
# adjacency_log_prob      -0.622931
# adjacency_entropy         0.03698
# Name: 65, dtype: object
# 66 loss                     0.745913
# conditional_log_prob   -64.994751
# expected_log_prob        -0.08803
# adjacency_log_prob      -0.621925
# adjacency_entropy        0.035957
# Name: 66, dtype: object
# 67 loss                     0.743941
# conditional_log_prob   -64.989131
# expected_log_prob       -0.088022
# adjacency_log_prob      -0.620952
# adjacency_entropy        0.034967
# Name: 67, dtype: object
# 68 loss                     0.742041
# conditional_log_prob   -64.934014
# expected_log_prob       -0.088022
# adjacency_log_prob       -0.62001
# adjacency_entropy        0.034009
# Name: 68, dtype: object
# 69 loss                     0.740194
# conditional_log_prob   -64.926875
# expected_log_prob       -0.088013
# adjacency_log_prob      -0.619099
# adjacency_entropy        0.033082
# Name: 69, dtype: object
# 70 loss                     0.738405
# conditional_log_prob   -64.921233
# expected_log_prob       -0.088005
# adjacency_log_prob      -0.618216
# adjacency_entropy        0.032184
# Name: 70, dtype: object
# 71 loss                     0.736676
# conditional_log_prob   -64.918014
# expected_log_prob       -0.088001
# adjacency_log_prob      -0.617361
# adjacency_entropy        0.031314
# Name: 71, dtype: object
# 72 loss                     0.734986
# conditional_log_prob   -64.889065
# expected_log_prob       -0.087982
# adjacency_log_prob      -0.616532
# adjacency_entropy        0.030471
# Name: 72, dtype: object
# 73 loss                     0.733366
# conditional_log_prob   -64.893853
# expected_log_prob       -0.087982
# adjacency_log_prob      -0.615729
# adjacency_entropy        0.029654
# Name: 73, dtype: object
# 74 loss                     0.731786
# conditional_log_prob   -64.887718
# expected_log_prob       -0.087974
# adjacency_log_prob       -0.61495
# adjacency_entropy        0.028862
# Name: 74, dtype: object
# 75 loss                     0.730258
# conditional_log_prob   -64.884558
# expected_log_prob       -0.087969
# adjacency_log_prob      -0.614195
# adjacency_entropy        0.028094
# Name: 75, dtype: object
# 76 loss                     0.728798
# conditional_log_prob   -64.834192
# expected_log_prob       -0.087987
# adjacency_log_prob      -0.613462
# adjacency_entropy        0.027348
# Name: 76, dtype: object
# 77 loss                     0.727359
# conditional_log_prob   -64.831489
# expected_log_prob       -0.087983
# adjacency_log_prob      -0.612751
# adjacency_entropy        0.026625
# Name: 77, dtype: object
# 78 loss                     0.725961
# conditional_log_prob   -64.828356
# expected_log_prob       -0.087978
# adjacency_log_prob       -0.61206
# adjacency_entropy        0.025923
# Name: 78, dtype: object
# 79 loss                     0.724604
# conditional_log_prob   -64.825091
# expected_log_prob       -0.087973
# adjacency_log_prob       -0.61139
# adjacency_entropy        0.025241
# Name: 79, dtype: object
# 80 loss                     0.723309
# conditional_log_prob   -64.784288
# expected_log_prob       -0.087991
# adjacency_log_prob      -0.610739
# adjacency_entropy        0.024579
# Name: 80, dtype: object
# 81 loss                     0.722033
# conditional_log_prob   -64.783963
# expected_log_prob        -0.08799
# adjacency_log_prob      -0.610107
# adjacency_entropy        0.023936
# Name: 81, dtype: object
# 82 loss                     0.720793
# conditional_log_prob   -64.783601
# expected_log_prob        -0.08799
# adjacency_log_prob      -0.609493
# adjacency_entropy        0.023311
# Name: 82, dtype: object
# 83 loss                     0.719584
# conditional_log_prob   -64.779509
# expected_log_prob       -0.087984
# adjacency_log_prob      -0.608896
# adjacency_entropy        0.022704
# Name: 83, dtype: object
# 84 loss                     0.718439
# conditional_log_prob   -64.778628
# expected_log_prob       -0.088009
# adjacency_log_prob      -0.608315
# adjacency_entropy        0.022114
# Name: 84, dtype: object
# 85 loss                       0.7173
# conditional_log_prob   -64.777809
# expected_log_prob       -0.088008
# adjacency_log_prob      -0.607751
# adjacency_entropy         0.02154
# Name: 85, dtype: object
# 86 loss                     0.716194
# conditional_log_prob   -64.778429
# expected_log_prob       -0.088008
# adjacency_log_prob      -0.607203
# adjacency_entropy        0.020983
# Name: 86, dtype: object
# 87 loss                     0.715115
# conditional_log_prob   -64.776336
# expected_log_prob       -0.088005
# adjacency_log_prob       -0.60667
# adjacency_entropy         0.02044
# Name: 87, dtype: object
# 88 loss                     0.714105
# conditional_log_prob   -64.780065
# expected_log_prob        -0.08804
# adjacency_log_prob      -0.606151
# adjacency_entropy        0.019913
# Name: 88, dtype: object
# 89 loss                     0.713089
# conditional_log_prob   -64.782502
# expected_log_prob       -0.088042
# adjacency_log_prob      -0.605647
# adjacency_entropy          0.0194
# Name: 89, dtype: object
# 90 loss                     0.712098
# conditional_log_prob   -64.781878
# expected_log_prob        -0.08804
# adjacency_log_prob      -0.605156
# adjacency_entropy        0.018901
# Name: 90, dtype: object
# 91 loss                     0.711132
# conditional_log_prob   -64.780594
# expected_log_prob       -0.088038
# adjacency_log_prob      -0.604679
# adjacency_entropy        0.018416
# Name: 91, dtype: object
# 92 loss                    0.710235
# conditional_log_prob   -64.78465
# expected_log_prob      -0.088077
# adjacency_log_prob     -0.604214
# adjacency_entropy       0.017944
# Name: 92, dtype: object
# 93 loss                     0.709328
# conditional_log_prob   -64.790179
# expected_log_prob       -0.088082
# adjacency_log_prob      -0.603762
# adjacency_entropy        0.017484
# Name: 93, dtype: object
# 94 loss                     0.708439
# conditional_log_prob   -64.790021
# expected_log_prob        -0.08808
# adjacency_log_prob      -0.603322
# adjacency_entropy        0.017037
# Name: 94, dtype: object
# 95 loss                     0.707574
# conditional_log_prob   -64.790111
# expected_log_prob       -0.088078
# adjacency_log_prob      -0.602894
# adjacency_entropy        0.016601
# Name: 95, dtype: object
# 96 loss                     0.706784
# conditional_log_prob   -64.810122
# expected_log_prob       -0.088129
# adjacency_log_prob      -0.602477
# adjacency_entropy        0.016177
# Name: 96, dtype: object
# 97 loss                      0.70597
# conditional_log_prob   -64.816863
# expected_log_prob       -0.088133
# adjacency_log_prob      -0.602072
# adjacency_entropy        0.015765
# Name: 97, dtype: object
# 98 loss                     0.705173
# conditional_log_prob   -64.818735
# expected_log_prob       -0.088133
# adjacency_log_prob      -0.601677
# adjacency_entropy        0.015363
# Name: 98, dtype: object
# 99 loss                     0.704394
# conditional_log_prob   -64.818662
# expected_log_prob        -0.08813
# adjacency_log_prob      -0.601292
# adjacency_entropy        0.014972
# Name: 99, dtype: object

# %%
fig, axs = plt.subplots(1, 5, figsize=(12, 3), layout="constrained")
axs[0].plot(df_log["loss"])
axs[0].set_title("Loss")
axs[1].plot(df_log["conditional_log_prob"])
axs[1].set_title("Conditional log prob")
axs[2].plot(df_log["expected_log_prob"])
axs[2].set_title("Expected log prob")
axs[3].plot(df_log["adjacency_log_prob"])
axs[3].set_title("Adjacency log prob")
axs[4].plot(df_log["adjacency_entropy"])
axs[4].set_title("Adjacency entropy")
fig.supxlabel("Epoch")
# Out:
# Text(0.5, 0.01, 'Epoch')

# %%
torch.save(decoder.state_dict(), "onehot_decoder.pt")

# %% [markdown]
# ## 4 Check and visualize the result

# %%
decoder.load_state_dict(torch.load("onehot_decoder.pt"))
# Out:
# /var/folders/jy/b494_d6d5zzc6hss2gyttx3r0000gq/T/ipykernel_93931/3502304886.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   decoder.load_state_dict(torch.load("onehot_decoder.pt"))
# <All keys matched successfully>

# %%
with torch.no_grad():
    decoder.eval()
    weight = decoder.weight
    # weight[:, torch.arange(n_neurons), torch.arange(n_neurons)] = (
    #     decoder.diag.weight.mean(dim=-1).reshape(-1, n_neurons)
    # )
    adjacency = decoder.adjacency.argmax(dim=-1) - 1

    fig, axs = plt.subplots(2, 4, figsize=(12, 6), layout="constrained")
    for state in range(n_states):
        ax = axs[0, state]
        ax.matshow(weight[state], vmin=-5, vmax=5, cmap="seismic")
        ax.set_title(f"State {state}")
        ax.set(xticks=[], yticks=[])

        ax = axs[1, state]
        ax.matshow(adjacency[state], vmin=-1, vmax=1, cmap="seismic")
        ax.set(xticks=[], yticks=[])

# %%
def plot_frame(ax):
    transform = np.array([[-1 / 2, np.sqrt(3) / 2], [-np.sqrt(3) / 2, -1 / 2]])
    radius = 40
    theta = 210 / 360 * 2 * np.pi
    start = np.array([radius * np.cos(theta), radius * np.sin(theta)])
    arm_length = 125
    theta = 330 / 360 * 2 * np.pi
    end = np.array([radius * np.cos(theta), radius * np.sin(theta)])
    one_arm = np.array(
        [
            [start[0], start[0], end[0], end[0]],
            [start[1], start[1] - arm_length, end[1] - arm_length, end[1]],
        ]
    )
    ax.plot(one_arm[0], one_arm[1], "k")
    one_arm = transform @ one_arm
    ax.plot(one_arm[0], one_arm[1], "k")
    one_arm = transform @ one_arm
    ax.plot(one_arm[0], one_arm[1], "k")

    # ax.text(0, -160, "root", fontsize=15, va="center", ha="center")
    ax.set_xlim(-160, 160)
    ax.set_ylim(-190, 130)
    ax.axis("off")
    ax.set_aspect("equal")


def plot_states(ax, behavior_ser, inferred_states, markersize: int = 6):
    trajectory_time = behavior_ser["trajectory"][:, 0]
    ax.matshow(inferred_states[None, :], vmin=0, vmax=9, cmap="tab10", aspect="auto")
    ax.set(xticks=[], yticks=[])

    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"

    trial_start_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_start_time"])
        / len(trajectory_time)
        * len(inferred_states)
    )
    trial_end_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_end_time"])
        / len(trajectory_time)
        * len(inferred_states)
    )
    ax.plot(trial_start_idx, 0, ">k", markersize=markersize)
    ax.plot(trial_end_idx, 0, marker, markersize=markersize)


def plot_soft_states(ax, behavior_ser, gamma, markersize: int = 6):
    trajectory_time = behavior_ser["trajectory"][:, 0]
    n_states = gamma.shape[1]
    for state in range(n_states):
        ax.matshow(
            state * np.ones((1, gamma.shape[0])),
            vmin=0,
            vmax=9,
            cmap="tab10",
            aspect="auto",
            alpha=gamma[None, :, state],
        )
    ax.set(xticks=[], yticks=[])

    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"

    trial_start_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_start_time"])
        / len(trajectory_time)
        * len(gamma)
    )
    trial_end_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_end_time"])
        / len(trajectory_time)
        * len(gamma)
    )
    ax.plot(trial_start_idx, 0, ">k", markersize=markersize)
    ax.plot(trial_end_idx, 0, marker, markersize=markersize)


def plot_trajectory(
    ax, behavior_ser: pd.Series, inferred_states: torch.Tensor, n_points: int | None = None, truncate: tuple[int|None, int|None] = (0, -1), markersize: int = 10
):
    theta = 185 / 360 * 2 * np.pi
    transform = np.array(
        [[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]
    )
    translation = np.array([155, 122])
    trial_start_position = behavior_ser["trial_start_position"]
    trial_start_position = transform @ trial_start_position + translation
    ax.plot(
        trial_start_position[0],
        trial_start_position[1],
        ">k",
        markersize=markersize,
    )
    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"
    if behavior_ser["light_position"] == "right":
        ax.add_patch(Circle((140, 90), 10, fc="gold", edgecolor="black"))
        ax.add_patch(Wedge((140, 80), 5, 180, 360, fc="none", edgecolor="black"))
    else:
        ax.add_patch(Circle((-140, 90), 10, fc="gold", edgecolor="black"))
        ax.add_patch(Wedge((-140, 80), 6, 180, 360, fc="none", edgecolor="black"))
    trial_end_position = behavior_ser["trial_end_position"]
    trial_end_position = transform @ trial_end_position + translation
    ax.plot(
        trial_end_position[0],
        trial_end_position[1],
        marker,
        markersize=markersize,
    )
    ax.text(0, 90, f"{behavior_ser["rule"]}", fontsize=15, ha="center", va="center")

    trajectory = behavior_ser["trajectory"][:, 1:]

    if n_points is None:
        n_points = min(len(trajectory), len(inferred_states))
    trajectory = trajectory[np.linspace(0, len(trajectory) - 1, n_points, dtype=int)]
    trajectory = trajectory @ transform.T + translation
    inferred_states = inferred_states[
        np.linspace(0, len(inferred_states) - 1, n_points, dtype=int)
    ]
    ax.scatter(
        trajectory[truncate[0]:truncate[1], 0],
        trajectory[truncate[0]:truncate[1], 1],
        c=inferred_states[truncate[0]:truncate[1]],
        vmin=0,
        vmax=9,
        cmap="tab10",
        s=1,
        zorder=10,
    )

# %%
n_rows = (n_trials - 1) // 5 + 1
n_points = 450
fig, axs = plt.subplots(n_rows, 5, figsize=(12, 2.2 * n_rows), layout="constrained")
axs = axs.flatten()

gamma_list = [None for _ in range(n_trials)]
inferred_states_list = [None for _ in range(n_trials)]

with torch.no_grad():
    for trial in range(n_trials):
    # for trial in range(5):
        x = spikes[trial]  # (n_time_bins, n_neurons)
        x_pred_mean = decoder(x)  # (n_states, n_time_bins, n_neurons)
        emission_log_prob = distributions.poisson_log_likelihood(
            x[None, :, :], x_pred_mean
        ).sum(dim=-1).T  # (n_time_bins, n_states)

        gamma_list[trial], _ = inference.forward_backward(
            emission_log_prob, decoder.transition_matrix, algorithm="logsumexp"
        )
        inferred_states_list[trial] = inference.viterbi(
            emission_log_prob, decoder.transition_matrix
        )
        ax = axs[trial]
        plot_frame(ax)
        plot_trajectory(ax, behavior.loc[trial], inferred_states_list[trial], n_points=n_points, truncate=(150, -1))
        ax_divider = make_axes_locatable(ax)
        ax_states = ax_divider.append_axes("top", size="20%", pad=0)
        plot_soft_states(ax_states, behavior.loc[trial], gamma_list[trial])
        # plot_states(ax_states, behavior.loc[trial], inferred_states_list[trial])


    for trial in range(n_trials, len(axs)):
        axs[trial].axis("off")

# %%
def make_video(behavior_ser, inferred_states, gamma, n_points = None):
    n_time_bins = inferred_states.shape[0]
    if n_points is None:
        n_points = min(len(trajectory), n_time_bins)
    
    fig, axs = plt.subplots(
        2,
        1,
        figsize=(4, 5),
        gridspec_kw={"height_ratios": [0.25, 1], "hspace": 0},
        layout="constrained",
    )
    axs[0].axis("off")
    axs[1].axis("off")

    states_inter = inferred_states[torch.linspace(0, n_time_bins - 1, n_points).to(torch.int64)]

    plot_frame(axs[1])
    plot_soft_states(axs[0], behavior_ser, gamma)
    plot_trajectory(axs[1], behavior_ser, inferred_states, n_points=n_points)
    (point,) = axs[1].plot(
        0,
        0,
        "o",
        markeredgecolor="k",
    )
    (line,) = axs[0].plot([0, 0], [-0.55, 0.55], "k", linewidth=2)

    theta = 185 / 360 * 2 * np.pi
    transform = np.array(
        [[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]
    )
    translation = np.array([155, 122])
    trajectory = behavior_ser["trajectory"][:, 1:]
    trajectory = trajectory[np.linspace(0, len(trajectory) - 1, n_points, dtype=int)]
    trajectory = trajectory @ transform.T + translation

    def animate(t):
        point.set(
            xdata=[trajectory[t, 0]],
            ydata=[trajectory[t, 1]],
            color=f"C{int(states_inter[t])}",
        )
        line.set(xdata=[t / n_points * n_time_bins, t / n_points * n_time_bins])
        return (point, line)

    # fig.suptitle(f"{method}, trial {trial}", fontsize=15)

    ani = animation.FuncAnimation(
        fig,
        animate,
        interval=1000 / 30,
        blit=False,  # blitting can't be used with Figure artists
        frames=np.arange(0, n_points),
        repeat_delay=100,
    )

    return ani

# %%
trial = 12
# trial = 18
ani = make_video(behavior.loc[trial], inferred_states_list[trial], gamma_list[trial], n_points=450)
ani.save(filename=f"{trial}.mp4", writer="ffmpeg", fps=30)

# %%
animation.writers.list()
# Out:
# ['pillow', 'html']
